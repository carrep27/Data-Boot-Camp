# %% [markdown]
# ## WeatherPy

# %%
# Dependencies
import openweathermapy.core as owm
import pandas as pd
import numpy as np
import random
from citipy import citipy 
import matplotlib.pyplot as plt
import requests
import time
from config import apikey

# %% [markdown]
# ## Gather Data

# %%
#Get random coordinates using import random. Latitude runs from 0 to 90 so we are asking for range +-90. Longtitude runs from
# 0 to 180 so we are asking for range +-180. 

#create empty lists we will append to
Latitude = []
Longitude = []
for x in range(0,1500):
    Latitude.append(random.uniform(-90,90))
    Longitude.append(random.uniform(-180,180))

#create dataframe for the latitude and longitude data we just collected. 

Cities = pd.DataFrame(columns = ["Latitude","Longitude"])
Cities["Latitude"] = Latitude
Cities["Longitude"] = Longitude

# %%
#Use Citiypy to get City closest to Coordinates

#create empty list we will append City name to
Cities1 =[]

#use iterrow to loop through Latitude and Longitude from DataFrame "Cities" we just created to get nearest city
for index, row in Cities.iterrows():
    City=citipy.nearest_city(row["Latitude"],row["Longitude"])
    Cities1.append(City.city_name)

#add the list of cities to the dataframe which already contains our Latitude and Longitude
Cities["City"]=Cities1

# %%
#remove any duplicate cities so only unique values. This is why we chose 1500 sets of random numbers....so that when 
#dupliates are elminated, we are left with at least 500 unique cities

new_data = Cities.drop_duplicates("City",keep="first")
print("We have " + str(len(new_data)) + " cities.")

# new_data
# Out:
# We have 614 cities.

# %%
#Utilize openweathermap api to get climate conditions at each city

units = "Imperial"
appid = apikey
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={apikey}&units={units}&q=" 


#create empty lists what we will append to with each API pull and set a city counter to 0
counter = 0
Temp = []
C = []
LTTE = []
LNGE = []
HUM = []
CL = []
WS = []


# Loop through the list of cities and perform a request for data on each
# because CityPy can return a City name that openweathermap might not recongize (for whatever reason), we utilize try/except

for index,row in new_data.iterrows():
    counter = counter + 1
    x=row["City"]
    q_url = query_url + str(x)
    response = requests.get(q_url).json()
    try:
        print(f"City #{counter}.") #print the # the city holds in our list (aka where we are in the loop)
        print(f"City name is {x} and its url is {q_url}.") #print the api url
        print("The City ID is " + str(response["id"]) + ".") #print the city id
        Temp.append(response['main']['temp']) #get the Temp (will be in farenheit cause we declared Imperial units)
        LNGE.append(response["coord"]["lon"]) #get Longitude
        LTTE.append(response["coord"]["lat"]) #get Latitue
        C.append(response["name"]) # get City Name
        HUM.append(response["main"]["humidity"]) #get Humidity
        CL.append(response["clouds"]["all"]) #get Cloudiness
        WS.append(response["wind"]["speed"]) #get WindSpeed (will be in mph cause we declared units Imperial)                       
    except: #if openweathermap cannot find a city, the city will be skipped and the message below will be prints
        print("This is not a city recognized in OpenWeatherMap.There will be no data for this city")
        pass
    print("------------------------------------------------------------------------------------")

#after cycling through the data, create a new data frame that contains all the info we just gathered and appended into lists
#first the dataframe and one column is created, and then each subsequent column is added
citydata=pd.DataFrame(columns = ["City"])

citydata["City"] = C
citydata["Longtitude"] = LNGE
citydata["Latitude"]=LTTE
citydata["Temperature"]= Temp
citydata["Humidity"] = HUM
citydata["Cloudiness"] = CL
citydata["Wind Speed"] = WS
# Out:
# City #1.
# City name is taolanaro and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=taolanaro.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #2.
# City name is thaba-tseka and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=thaba-tseka.
# The City ID is 1106835.
# ------------------------------------------------------------------------------------
# City #3.
# City name is pudozh and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=pudozh.
# The City ID is 504269.
# ------------------------------------------------------------------------------------
# City #4.
# City name is bredasdorp and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=bredasdorp.
# The City ID is 1015776.
# ------------------------------------------------------------------------------------
# City #5.
# City name is tuktoyaktuk and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=tuktoyaktuk.
# The City ID is 6170031.
# ------------------------------------------------------------------------------------
# City #6.
# City name is sinnamary and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=sinnamary.
# The City ID is 3380290.
# ------------------------------------------------------------------------------------
# City #7.
# City name is kahului and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=kahului.
# The City ID is 5847411.
# ------------------------------------------------------------------------------------
# City #8.
# City name is bluff and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=bluff.
# The City ID is 2175403.
# ------------------------------------------------------------------------------------
# City #9.
# City name is rikitea and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=rikitea.
# The City ID is 4030556.
# ------------------------------------------------------------------------------------
# City #10.
# City name is port lincoln and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=port lincoln.
# The City ID is 2063036.
# ------------------------------------------------------------------------------------
# City #11.
# City name is georgetown and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=georgetown.
# The City ID is 3378644.
# ------------------------------------------------------------------------------------
# City #12.
# City name is broken hill and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=broken hill.
# The City ID is 2173911.
# ------------------------------------------------------------------------------------
# City #13.
# City name is vao and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=vao.
# The City ID is 588365.
# ------------------------------------------------------------------------------------
# City #14.
# City name is barentsburg and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=barentsburg.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #15.
# City name is jamestown and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=jamestown.
# The City ID is 2069194.
# ------------------------------------------------------------------------------------
# City #16.
# City name is miri and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=miri.
# The City ID is 2347470.
# ------------------------------------------------------------------------------------
# City #17.
# City name is cape town and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=cape town.
# The City ID is 3369157.
# ------------------------------------------------------------------------------------
# City #18.
# City name is hoquiam and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=hoquiam.
# The City ID is 5797693.
# ------------------------------------------------------------------------------------
# City #19.
# City name is upernavik and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=upernavik.
# The City ID is 3418910.
# ------------------------------------------------------------------------------------
# City #20.
# City name is jombang and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=jombang.
# The City ID is 1642414.
# ------------------------------------------------------------------------------------
# City #21.
# City name is cape canaveral and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=cape canaveral.
# The City ID is 4149959.
# ------------------------------------------------------------------------------------
# City #22.
# City name is sulzbach-rosenberg and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=sulzbach-rosenberg.
# The City ID is 2824801.
# ------------------------------------------------------------------------------------
# City #23.
# City name is kudahuvadhoo and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=kudahuvadhoo.
# The City ID is 1337607.
# ------------------------------------------------------------------------------------
# City #24.
# City name is college and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=college.
# The City ID is 5859699.
# ------------------------------------------------------------------------------------
# City #25.
# City name is mataura and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=mataura.
# The City ID is 6201424.
# ------------------------------------------------------------------------------------
# City #26.
# City name is poum and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=poum.
# The City ID is 787487.
# ------------------------------------------------------------------------------------
# City #27.
# City name is ushuaia and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=ushuaia.
# The City ID is 3833367.
# ------------------------------------------------------------------------------------
# City #28.
# City name is emba and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=emba.
# The City ID is 146639.
# ------------------------------------------------------------------------------------
# City #29.
# City name is batticaloa and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=batticaloa.
# The City ID is 1250161.
# ------------------------------------------------------------------------------------
# City #30.
# City name is peleduy and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=peleduy.
# The City ID is 2018069.
# ------------------------------------------------------------------------------------
# City #31.
# City name is mersing and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=mersing.
# The City ID is 1732826.
# ------------------------------------------------------------------------------------
# City #32.
# City name is butaritari and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=butaritari.
# The City ID is 2110227.
# ------------------------------------------------------------------------------------
# City #33.
# City name is skagastrond and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=skagastrond.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #34.
# City name is carnarvon and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=carnarvon.
# The City ID is 1014034.
# ------------------------------------------------------------------------------------
# City #35.
# City name is mahebourg and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=mahebourg.
# The City ID is 934322.
# ------------------------------------------------------------------------------------
# City #36.
# City name is fukue and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=fukue.
# The City ID is 1848373.
# ------------------------------------------------------------------------------------
# City #37.
# City name is port alfred and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=port alfred.
# The City ID is 964432.
# ------------------------------------------------------------------------------------
# City #38.
# City name is manokwari and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=manokwari.
# The City ID is 1636308.
# ------------------------------------------------------------------------------------
# City #39.
# City name is ucluelet and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=ucluelet.
# The City ID is 6171633.
# ------------------------------------------------------------------------------------
# City #40.
# City name is lagoa and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=lagoa.
# The City ID is 2267254.
# ------------------------------------------------------------------------------------
# City #41.
# City name is salina cruz and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=salina cruz.
# The City ID is 3520064.
# ------------------------------------------------------------------------------------
# City #42.
# City name is hithadhoo and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=hithadhoo.
# The City ID is 1282256.
# ------------------------------------------------------------------------------------
# City #43.
# City name is carmen and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=carmen.
# The City ID is 1718338.
# ------------------------------------------------------------------------------------
# City #44.
# City name is buariki and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=buariki.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #45.
# City name is ribeira grande and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=ribeira grande.
# The City ID is 3372707.
# ------------------------------------------------------------------------------------
# City #46.
# City name is nanortalik and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=nanortalik.
# The City ID is 3421765.
# ------------------------------------------------------------------------------------
# City #47.
# City name is puerto ayora and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=puerto ayora.
# The City ID is 3652764.
# ------------------------------------------------------------------------------------
# City #48.
# City name is kapaa and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=kapaa.
# The City ID is 5848280.
# ------------------------------------------------------------------------------------
# City #49.
# City name is airai and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=airai.
# The City ID is 1651810.
# ------------------------------------------------------------------------------------
# City #50.
# City name is isangel and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=isangel.
# The City ID is 2136825.
# ------------------------------------------------------------------------------------
# City #51.
# City name is fort nelson and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=fort nelson.
# The City ID is 5955902.
# ------------------------------------------------------------------------------------
# City #52.
# City name is baker city and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=baker city.
# The City ID is 5712169.
# ------------------------------------------------------------------------------------
# City #53.
# City name is east london and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=east london.
# The City ID is 1006984.
# ------------------------------------------------------------------------------------
# City #54.
# City name is fortuna and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=fortuna.
# The City ID is 2517679.
# ------------------------------------------------------------------------------------
# City #55.
# City name is shingu and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=shingu.
# The City ID is 1847947.
# ------------------------------------------------------------------------------------
# City #56.
# City name is hobart and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=hobart.
# The City ID is 2163355.
# ------------------------------------------------------------------------------------
# City #57.
# City name is pitrufquen and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=pitrufquen.
# The City ID is 3875746.
# ------------------------------------------------------------------------------------
# City #58.
# City name is tripoli and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=tripoli.
# The City ID is 252601.
# ------------------------------------------------------------------------------------
# City #59.
# City name is tikheron and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=tikheron.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #60.
# City name is provideniya and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=provideniya.
# The City ID is 4031574.
# ------------------------------------------------------------------------------------
# City #61.
# City name is atuona and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=atuona.
# The City ID is 4020109.
# ------------------------------------------------------------------------------------
# City #62.
# City name is kaduqli and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=kaduqli.
# The City ID is 373141.
# ------------------------------------------------------------------------------------
# City #63.
# City name is talnakh and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=talnakh.
# The City ID is 1490256.
# ------------------------------------------------------------------------------------
# City #64.
# City name is punta arenas and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=punta arenas.
# The City ID is 3874787.
# ------------------------------------------------------------------------------------
# City #65.
# City name is teguise and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=teguise.
# The City ID is 2510573.
# ------------------------------------------------------------------------------------
# City #66.
# City name is dolores and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=dolores.
# The City ID is 3435038.
# ------------------------------------------------------------------------------------
# City #67.
# City name is juneau and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=juneau.
# The City ID is 5554072.
# ------------------------------------------------------------------------------------
# City #68.
# City name is bereda and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=bereda.
# The City ID is 3105522.
# ------------------------------------------------------------------------------------
# City #69.
# City name is victoria and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=victoria.
# The City ID is 1733782.
# ------------------------------------------------------------------------------------
# City #70.
# City name is kuche and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=kuche.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #71.
# City name is ponta do sol and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=ponta do sol.
# The City ID is 3453439.
# ------------------------------------------------------------------------------------
# City #72.
# City name is tiksi and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=tiksi.
# The City ID is 2015306.
# ------------------------------------------------------------------------------------
# City #73.
# City name is eureka and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=eureka.
# The City ID is 5563397.
# ------------------------------------------------------------------------------------
# City #74.
# City name is albany and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=albany.
# The City ID is 5106834.
# ------------------------------------------------------------------------------------
# City #75.
# City name is busselton and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=busselton.
# The City ID is 2075265.
# ------------------------------------------------------------------------------------
# City #76.
# City name is new norfolk and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=new norfolk.
# The City ID is 2155415.
# ------------------------------------------------------------------------------------
# City #77.
# City name is heihe and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=heihe.
# The City ID is 2036973.
# ------------------------------------------------------------------------------------
# City #78.
# City name is erzin and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=erzin.
# The City ID is 296852.
# ------------------------------------------------------------------------------------
# City #79.
# City name is codrington and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=codrington.
# The City ID is 2160063.
# ------------------------------------------------------------------------------------
# City #80.
# City name is berestechko and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=berestechko.
# The City ID is 712416.
# ------------------------------------------------------------------------------------
# City #81.
# City name is kedrovyy and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=kedrovyy.
# The City ID is 1538641.
# ------------------------------------------------------------------------------------
# City #82.
# City name is mar del plata and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=mar del plata.
# The City ID is 3863379.
# ------------------------------------------------------------------------------------
# City #83.
# City name is volkhovskiy and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=volkhovskiy.
# The City ID is 472714.
# ------------------------------------------------------------------------------------
# City #84.
# City name is mazatlan and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=mazatlan.
# The City ID is 3996322.
# ------------------------------------------------------------------------------------
# City #85.
# City name is nedelino and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=nedelino.
# The City ID is 728851.
# ------------------------------------------------------------------------------------
# City #86.
# City name is dikson and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=dikson.
# The City ID is 1507390.
# ------------------------------------------------------------------------------------
# City #87.
# City name is narsaq and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=narsaq.
# The City ID is 3421719.
# ------------------------------------------------------------------------------------
# City #88.
# City name is coahuayana and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=coahuayana.
# The City ID is 3981460.
# ------------------------------------------------------------------------------------
# City #89.
# City name is arman and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=arman.
# The City ID is 2127060.
# ------------------------------------------------------------------------------------
# City #90.
# City name is dunedin and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=dunedin.
# The City ID is 2191562.
# ------------------------------------------------------------------------------------
# City #91.
# City name is ust-omchug and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=ust-omchug.
# The City ID is 2120047.
# ------------------------------------------------------------------------------------
# City #92.
# City name is ambulu and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=ambulu.
# The City ID is 1621313.
# ------------------------------------------------------------------------------------
# City #93.
# City name is lorengau and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=lorengau.
# The City ID is 2092164.
# ------------------------------------------------------------------------------------
# City #94.
# City name is hermanus and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=hermanus.
# The City ID is 3366880.
# ------------------------------------------------------------------------------------
# City #95.
# City name is sakakah and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=sakakah.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #96.
# City name is saleaula and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=saleaula.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #97.
# City name is karlovo and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=karlovo.
# The City ID is 730565.
# ------------------------------------------------------------------------------------
# City #98.
# City name is ormara and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=ormara.
# The City ID is 1168700.
# ------------------------------------------------------------------------------------
# City #99.
# City name is vestmanna and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=vestmanna.
# The City ID is 2610343.
# ------------------------------------------------------------------------------------
# City #100.
# City name is avarua and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=avarua.
# The City ID is 4035715.
# ------------------------------------------------------------------------------------
# City #101.
# City name is bonfim and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=bonfim.
# The City ID is 3451126.
# ------------------------------------------------------------------------------------
# City #102.
# City name is hasaki and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=hasaki.
# The City ID is 2112802.
# ------------------------------------------------------------------------------------
# City #103.
# City name is manta and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=manta.
# The City ID is 685981.
# ------------------------------------------------------------------------------------
# City #104.
# City name is ponta delgada and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=ponta delgada.
# The City ID is 3372783.
# ------------------------------------------------------------------------------------
# City #105.
# City name is osoyoos and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=osoyoos.
# The City ID is 6094665.
# ------------------------------------------------------------------------------------
# City #106.
# City name is sao joao da barra and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=sao joao da barra.
# The City ID is 3448903.
# ------------------------------------------------------------------------------------
# City #107.
# City name is mount abu and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=mount abu.
# The City ID is 1279394.
# ------------------------------------------------------------------------------------
# City #108.
# City name is arraial do cabo and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=arraial do cabo.
# The City ID is 3471451.
# ------------------------------------------------------------------------------------
# City #109.
# City name is luderitz and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=luderitz.
# The City ID is 3355672.
# ------------------------------------------------------------------------------------
# City #110.
# City name is khomeyn and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=khomeyn.
# The City ID is 127403.
# ------------------------------------------------------------------------------------
# City #111.
# City name is petropavlovsk-kamchatskiy and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=petropavlovsk-kamchatskiy.
# The City ID is 2122104.
# ------------------------------------------------------------------------------------
# City #112.
# City name is vaitupu and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=vaitupu.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #113.
# City name is ksenyevka and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=ksenyevka.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #114.
# City name is horki and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=horki.
# The City ID is 627905.
# ------------------------------------------------------------------------------------
# City #115.
# City name is qaanaaq and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=qaanaaq.
# The City ID is 3831208.
# ------------------------------------------------------------------------------------
# City #116.
# City name is flin flon and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=flin flon.
# The City ID is 5954718.
# ------------------------------------------------------------------------------------
# City #117.
# City name is chuy and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=chuy.
# The City ID is 3443061.
# ------------------------------------------------------------------------------------
# City #118.
# City name is sidi bu zayd and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=sidi bu zayd.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #119.
# City name is ardistan and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=ardistan.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #120.
# City name is ouadda and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=ouadda.
# The City ID is 236901.
# ------------------------------------------------------------------------------------
# City #121.
# City name is kalmunai and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=kalmunai.
# The City ID is 1242110.
# ------------------------------------------------------------------------------------
# City #122.
# City name is ahipara and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=ahipara.
# The City ID is 2194098.
# ------------------------------------------------------------------------------------
# City #123.
# City name is lavrentiya and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=lavrentiya.
# The City ID is 4031637.
# ------------------------------------------------------------------------------------
# City #124.
# City name is padang and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=padang.
# The City ID is 1633419.
# ------------------------------------------------------------------------------------
# City #125.
# City name is zhanakorgan and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=zhanakorgan.
# The City ID is 1517323.
# ------------------------------------------------------------------------------------
# City #126.
# City name is peto and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=peto.
# The City ID is 3521596.
# ------------------------------------------------------------------------------------
# City #127.
# City name is nikolskoye and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=nikolskoye.
# The City ID is 546105.
# ------------------------------------------------------------------------------------
# City #128.
# City name is byron bay and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=byron bay.
# The City ID is 2172880.
# ------------------------------------------------------------------------------------
# City #129.
# City name is barrow and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=barrow.
# The City ID is 3833859.
# ------------------------------------------------------------------------------------
# City #130.
# City name is anadyr and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=anadyr.
# The City ID is 2127202.
# ------------------------------------------------------------------------------------
# City #131.
# City name is amderma and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=amderma.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #132.
# City name is hobyo and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=hobyo.
# The City ID is 57000.
# ------------------------------------------------------------------------------------
# City #133.
# City name is kota kinabalu and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=kota kinabalu.
# The City ID is 1733432.
# ------------------------------------------------------------------------------------
# City #134.
# City name is canoa and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=canoa.
# The City ID is 3566054.
# ------------------------------------------------------------------------------------
# City #135.
# City name is port elizabeth and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=port elizabeth.
# The City ID is 4501427.
# ------------------------------------------------------------------------------------
# City #136.
# City name is porto novo and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=porto novo.
# The City ID is 6322184.
# ------------------------------------------------------------------------------------
# City #137.
# City name is mys shmidta and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=mys shmidta.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #138.
# City name is iqaluit and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=iqaluit.
# The City ID is 5983720.
# ------------------------------------------------------------------------------------
# City #139.
# City name is mareeba and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=mareeba.
# The City ID is 2158767.
# ------------------------------------------------------------------------------------
# City #140.
# City name is nelson bay and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=nelson bay.
# The City ID is 2155562.
# ------------------------------------------------------------------------------------
# City #141.
# City name is tasiilaq and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=tasiilaq.
# The City ID is 3424607.
# ------------------------------------------------------------------------------------
# City #142.
# City name is severodvinsk and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=severodvinsk.
# The City ID is 496285.
# ------------------------------------------------------------------------------------
# City #143.
# City name is alyangula and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=alyangula.
# The City ID is 2079582.
# ------------------------------------------------------------------------------------
# City #144.
# City name is ilulissat and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=ilulissat.
# The City ID is 3423146.
# ------------------------------------------------------------------------------------
# City #145.
# City name is vestmannaeyjar and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=vestmannaeyjar.
# The City ID is 3412093.
# ------------------------------------------------------------------------------------
# City #146.
# City name is marcona and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=marcona.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #147.
# City name is mogadishu and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=mogadishu.
# The City ID is 53654.
# ------------------------------------------------------------------------------------
# City #148.
# City name is monte alegre and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=monte alegre.
# The City ID is 3394605.
# ------------------------------------------------------------------------------------
# City #149.
# City name is kosa and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=kosa.
# The City ID is 544318.
# ------------------------------------------------------------------------------------
# City #150.
# City name is saskylakh and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=saskylakh.
# The City ID is 2017155.
# ------------------------------------------------------------------------------------
# City #151.
# City name is dicabisagan and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=dicabisagan.
# The City ID is 1715015.
# ------------------------------------------------------------------------------------
# City #152.
# City name is sitio novo do tocantins and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=sitio novo do tocantins.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #153.
# City name is jinchang and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=jinchang.
# The City ID is 1805733.
# ------------------------------------------------------------------------------------
# City #154.
# City name is broome and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=broome.
# The City ID is 2656067.
# ------------------------------------------------------------------------------------
# City #155.
# City name is hilo and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=hilo.
# The City ID is 5855927.
# ------------------------------------------------------------------------------------
# City #156.
# City name is norman wells and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=norman wells.
# The City ID is 6089245.
# ------------------------------------------------------------------------------------
# City #157.
# City name is kemalpasa and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=kemalpasa.
# The City ID is 308224.
# ------------------------------------------------------------------------------------
# City #158.
# City name is shenjiamen and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=shenjiamen.
# The City ID is 1795632.
# ------------------------------------------------------------------------------------
# City #159.
# City name is blonduos and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=blonduos.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #160.
# City name is khuzdar and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=khuzdar.
# The City ID is 7082481.
# ------------------------------------------------------------------------------------
# City #161.
# City name is bahia blanca and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=bahia blanca.
# The City ID is 3865086.
# ------------------------------------------------------------------------------------
# City #162.
# City name is kruisfontein and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=kruisfontein.
# The City ID is 986717.
# ------------------------------------------------------------------------------------
# City #163.
# City name is iranshahr and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=iranshahr.
# The City ID is 1160939.
# ------------------------------------------------------------------------------------
# City #164.
# City name is yellowknife and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=yellowknife.
# The City ID is 6185377.
# ------------------------------------------------------------------------------------
# City #165.
# City name is faanui and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=faanui.
# The City ID is 4034551.
# ------------------------------------------------------------------------------------
# City #166.
# City name is jiaojiang and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=jiaojiang.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #167.
# City name is kaitangata and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=kaitangata.
# The City ID is 2208248.
# ------------------------------------------------------------------------------------
# City #168.
# City name is taybad and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=taybad.
# The City ID is 1159384.
# ------------------------------------------------------------------------------------
# City #169.
# City name is vaini and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=vaini.
# The City ID is 1273574.
# ------------------------------------------------------------------------------------
# City #170.
# City name is burns lake and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=burns lake.
# The City ID is 5911745.
# ------------------------------------------------------------------------------------
# City #171.
# City name is tilichiki and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=tilichiki.
# The City ID is 2120591.
# ------------------------------------------------------------------------------------
# City #172.
# City name is grand river south east and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=grand river south east.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #173.
# City name is bolungarvik and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=bolungarvik.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# ...
# The City ID is 2123814.
# ------------------------------------------------------------------------------------
# City #557.
# City name is sevierville and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=sevierville.
# The City ID is 4656585.
# ------------------------------------------------------------------------------------
# City #558.
# City name is gidam and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=gidam.
# The City ID is 1271215.
# ------------------------------------------------------------------------------------
# City #559.
# City name is kushiro and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=kushiro.
# The City ID is 2129072.
# ------------------------------------------------------------------------------------
# City #560.
# City name is saint-augustin and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=saint-augustin.
# The City ID is 3031582.
# ------------------------------------------------------------------------------------
# City #561.
# City name is henties bay and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=henties bay.
# The City ID is 3356832.
# ------------------------------------------------------------------------------------
# City #562.
# City name is burnie and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=burnie.
# The City ID is 2173125.
# ------------------------------------------------------------------------------------
# City #563.
# City name is tynda and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=tynda.
# The City ID is 2014718.
# ------------------------------------------------------------------------------------
# City #564.
# City name is chapais and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=chapais.
# The City ID is 5919850.
# ------------------------------------------------------------------------------------
# City #565.
# City name is zhigansk and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=zhigansk.
# The City ID is 2012530.
# ------------------------------------------------------------------------------------
# City #566.
# City name is igrim and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=igrim.
# The City ID is 1505965.
# ------------------------------------------------------------------------------------
# City #567.
# City name is pimentel and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=pimentel.
# The City ID is 3389609.
# ------------------------------------------------------------------------------------
# City #568.
# City name is velsk and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=velsk.
# The City ID is 475938.
# ------------------------------------------------------------------------------------
# City #569.
# City name is eyl and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=eyl.
# The City ID is 60019.
# ------------------------------------------------------------------------------------
# City #570.
# City name is soe and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=soe.
# The City ID is 587876.
# ------------------------------------------------------------------------------------
# City #571.
# City name is manaus and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=manaus.
# The City ID is 3663517.
# ------------------------------------------------------------------------------------
# City #572.
# City name is fenoarivo and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=fenoarivo.
# The City ID is 1070940.
# ------------------------------------------------------------------------------------
# City #573.
# City name is oyama and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=oyama.
# The City ID is 1853483.
# ------------------------------------------------------------------------------------
# City #574.
# City name is ajdabiya and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=ajdabiya.
# The City ID is 89113.
# ------------------------------------------------------------------------------------
# City #575.
# City name is north bend and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=north bend.
# The City ID is 5742974.
# ------------------------------------------------------------------------------------
# City #576.
# City name is shorapani and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=shorapani.
# The City ID is 611964.
# ------------------------------------------------------------------------------------
# City #577.
# City name is kilindoni and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=kilindoni.
# The City ID is 157429.
# ------------------------------------------------------------------------------------
# City #578.
# City name is kailua and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=kailua.
# The City ID is 5847486.
# ------------------------------------------------------------------------------------
# City #579.
# City name is gari and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=gari.
# The City ID is 1506676.
# ------------------------------------------------------------------------------------
# City #580.
# City name is puerto penasco and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=puerto penasco.
# The City ID is 3991347.
# ------------------------------------------------------------------------------------
# City #581.
# City name is zemio and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=zemio.
# The City ID is 235826.
# ------------------------------------------------------------------------------------
# City #582.
# City name is tuatapere and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=tuatapere.
# The City ID is 2180815.
# ------------------------------------------------------------------------------------
# City #583.
# City name is puerto madryn and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=puerto madryn.
# The City ID is 3840092.
# ------------------------------------------------------------------------------------
# City #584.
# City name is katherine and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=katherine.
# The City ID is 2068655.
# ------------------------------------------------------------------------------------
# City #585.
# City name is lompoc and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=lompoc.
# The City ID is 5367788.
# ------------------------------------------------------------------------------------
# City #586.
# City name is santa cruz del sur and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=santa cruz del sur.
# The City ID is 3537840.
# ------------------------------------------------------------------------------------
# City #587.
# City name is dabakala and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=dabakala.
# The City ID is 2290609.
# ------------------------------------------------------------------------------------
# City #588.
# City name is paldiski and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=paldiski.
# The City ID is 589663.
# ------------------------------------------------------------------------------------
# City #589.
# City name is lakes entrance and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=lakes entrance.
# The City ID is 2160735.
# ------------------------------------------------------------------------------------
# City #590.
# City name is sheltozero and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=sheltozero.
# The City ID is 494970.
# ------------------------------------------------------------------------------------
# City #591.
# City name is san quintin and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=san quintin.
# The City ID is 1688687.
# ------------------------------------------------------------------------------------
# City #592.
# City name is krasnoselkup and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=krasnoselkup.
# This is not a city recognized in OpenWeatherMap.There will be no data for this city
# ------------------------------------------------------------------------------------
# City #593.
# City name is vilhena and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=vilhena.
# The City ID is 3924679.
# ------------------------------------------------------------------------------------
# City #594.
# City name is nagato and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=nagato.
# The City ID is 1899102.
# ------------------------------------------------------------------------------------
# City #595.
# City name is port hedland and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=port hedland.
# The City ID is 2063042.
# ------------------------------------------------------------------------------------
# City #596.
# City name is juba and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=juba.
# The City ID is 587450.
# ------------------------------------------------------------------------------------
# City #597.
# City name is sioux lookout and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=sioux lookout.
# The City ID is 6148373.
# ------------------------------------------------------------------------------------
# City #598.
# City name is mae sai and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=mae sai.
# The City ID is 1152194.
# ------------------------------------------------------------------------------------
# City #599.
# City name is beroroha and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=beroroha.
# The City ID is 1066831.
# ------------------------------------------------------------------------------------
# City #600.
# City name is kabanjahe and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=kabanjahe.
# The City ID is 1214965.
# ------------------------------------------------------------------------------------
# City #601.
# City name is tottori and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=tottori.
# The City ID is 1849892.
# ------------------------------------------------------------------------------------
# City #602.
# City name is cap-aux-meules and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=cap-aux-meules.
# The City ID is 5915327.
# ------------------------------------------------------------------------------------
# City #603.
# City name is mwinilunga and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=mwinilunga.
# The City ID is 902620.
# ------------------------------------------------------------------------------------
# City #604.
# City name is mutis and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=mutis.
# The City ID is 3689325.
# ------------------------------------------------------------------------------------
# City #605.
# City name is satis and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=satis.
# The City ID is 498421.
# ------------------------------------------------------------------------------------
# City #606.
# City name is marsh harbour and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=marsh harbour.
# The City ID is 3571913.
# ------------------------------------------------------------------------------------
# City #607.
# City name is maromitsa and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=maromitsa.
# The City ID is 529051.
# ------------------------------------------------------------------------------------
# City #608.
# City name is geraldton and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=geraldton.
# The City ID is 5960603.
# ------------------------------------------------------------------------------------
# City #609.
# City name is dzilam gonzalez and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=dzilam gonzalez.
# The City ID is 3529654.
# ------------------------------------------------------------------------------------
# City #610.
# City name is santa vitoria do palmar and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=santa vitoria do palmar.
# The City ID is 3449747.
# ------------------------------------------------------------------------------------
# City #611.
# City name is leh and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=leh.
# The City ID is 1264976.
# ------------------------------------------------------------------------------------
# City #612.
# City name is tucurui and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=tucurui.
# The City ID is 3385935.
# ------------------------------------------------------------------------------------
# City #613.
# City name is saint-georges and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=saint-georges.
# The City ID is 6295855.
# ------------------------------------------------------------------------------------
# City #614.
# City name is pacific grove and its url is http://api.openweathermap.org/data/2.5/weather?appid=074b0d7d1323371221cd9dce8e15094a&units=Imperial&q=pacific grove.
# The City ID is 5380437.
# ------------------------------------------------------------------------------------

# %%
#print head of datafram to verify it looks ok
citydata.head()
# Out:
#           City  Longtitude  Latitude  Temperature  Humidity  Cloudiness  \
# 0  Thaba-Tseka       28.61    -29.52        52.21        90          12
# 1       Pudozh       36.54     61.81        -5.66        71          32
# 2   Bredasdorp       20.04    -34.53        68.00        88          92
# 3  Tuktoyaktuk     -133.03     69.44         6.60        84          20
# 4    Sinnamary      -52.96      5.38        80.74        94          92
#
#    Wind Speed
# 0        2.71
# 1        4.72
# 2        4.70
# 3        4.70
# 4       12.44

# %% [markdown]
# ## Temp Vs Latitude

# %%
#Temp vs Latitude Graph

#set x value as Latitude and y as Temperature. Then repeat with humidity, cloudiness and windspeed.

xvalue = citydata["Latitude"]
yvalue = citydata["Temperature"]

plt.title("Temperature Vs Latitude (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Temperature in Farenheit")

plt.scatter(xvalue, yvalue, marker="o", color="red", edgecolor="black")
plt.savefig("Temp Vs Latitude.png")
plt.show()

# %% [markdown]
# # Humidity vs Latitude

# %%
#Humidity vs Latitude Graph

xvalue = citydata["Latitude"]
yvalue = citydata["Humidity"]

plt.title("Humidity Vs Latitude (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.scatter(xvalue, yvalue, marker="o", color="blue", edgecolor="black")
plt.savefig("Humidity Vs Latitude.png")
plt.show()

# %% [markdown]
# ## Cloudiness vs Latitude

# %%
#Cloudiness vs Latitude Graph
xvalue = citydata["Latitude"]
yvalue = citydata["Cloudiness"]

plt.title("Cloudiness vs Latitude (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.scatter(xvalue, yvalue, marker="o", color="green", edgecolor="black")
plt.savefig("Cloudiness Vs Latitude.png")
plt.show()

# %% [markdown]
# ## Wind Speed vs Latitude

# %%
#Wind Speed vs Latitude Graph
xvalue = citydata["Latitude"]
yvalue = citydata["Wind Speed"]

plt.title("Wind Speed (mph) Vs Latitude (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.scatter(xvalue, yvalue, marker="o", color="orange", edgecolor="black")
plt.savefig("Wind Speed in mph Vs Latitude.png")
plt.show()

# %% [markdown]
# ## Analysis

# %%
#There appears to be a strong relationship between Temperature and distance from the equator. The farther one is away from
#the equator (Lat= 0), the colder it gets


#There doesnt seem to be a very strong correlation with Wind Speed or Cloudiness with Latitude
#There appears to be more cities in the Northern Hemisphere than Southern.
